# %%
#Quantizing an image with KMeans clustering

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import imageio.v2 as imageio

# Read the image
img = imageio.imread("headshot.jpg")

# Display the image
plt.figure(figsize=(10, 7))
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.show()

# %%
img.shape
# Out:
# (379, 337, 3)

# %%
x, y, z = img.shape
long_img = img.reshape(x*y, z)
long_img.shape
# Out:
# (127723, 3)

# %%
from sklearn import cluster
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(long_img)
centers = k_means.cluster_centers_
centers
# Out:
# array([[ 58.09595307, 123.75847668, 168.45401213],
#        [182.3713479 , 193.38786521, 153.89797974],
#        [ 44.65342368,  90.45865894, 112.56270834],
#        [165.35885027, 129.02199736, 102.95556533],
#        [ 78.11082326, 184.69602763, 236.60909614]])

# %%
labels = k_means.labels_
labels
# Out:
# array([1, 1, 1, ..., 4, 4, 4], dtype=int32)

# %%
plt.figure(figsize = (10,7))
plt.imshow(centers[labels].reshape(x, y, z))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
