# %%
#Using KMeans to cluster data

# %%
import numpy as np
import pandas as pd
 
from sklearn.datasets import make_blobs
blobs, classes = make_blobs(500, centers=3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f, ax = plt.subplots(figsize=(7.5, 7.5))
rgb = np.array(['r', 'g', 'b'])
ax.scatter(blobs[:, 0], blobs[:, 1], color=rgb[classes])
ax.set_title("Blobs")
# Out:
# Text(0.5, 1.0, 'Blobs')

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters=3)

kmean.fit(blobs)
# Out:
# KMeans(n_clusters=3)

# %%
kmean.cluster_centers_
# Out:
# array([[ 4.66992234, -0.53935219],
#        [ 9.69470533, -9.28844777],
#        [-0.76486524, -2.55024637]])

# %%
f, ax = plt.subplots(figsize=(7.5, 7.5))
ax.scatter(blobs[:, 0], blobs[:, 1], color=rgb[classes])
ax.scatter(kmean.cluster_centers_[:, 0],kmean.cluster_centers_[:, 1], marker='*', s=250,color='black', label='Centers')
ax.set_title("Blobs")
ax.legend(loc='best')

# %%
kmean.labels_[:5]
# Out:
# array([0, 2, 2, 0, 0], dtype=int32)

# %%
classes[:5]
# Out:
# array([0, 1, 1, 0, 0])

# %%
kmean.transform(blobs)[:5]
# Out:
# array([[ 1.65117104, 11.67748695,  6.23080741],
#        [ 4.65499774, 11.29780768,  1.30513507],
#        [ 5.30696864, 13.08480459,  1.35534817],
#        [ 0.39163116, 10.42488553,  5.54485517],
#        [ 1.49704763, 10.83392027,  7.06400326]])
